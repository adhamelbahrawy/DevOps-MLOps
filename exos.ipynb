# %%
import pandas as pd
from numpy import nan

# %% [markdown]
# # Exercice 0

# %%
df = pd.read_csv("SeaCareerSet.csv")

# %% [markdown]
# # Exercice 1

# %% [markdown]
# ## 1

# %%
df.head()
# Out:
#    passenger_id                                               name     sex  \
# 0           334                    Vander Planke, Mr. Leo Edmondus    male
# 1           178                         Isham, Miss. Ann Elizabeth  female
# 2           320  Spedden, Mrs. Frederic Oakley (Margaretta Corn...  female
# 3           267                          Panula, Mr. Ernesti Arvid    male
# 4           489                      Somerton, Mr. Francis William    male
#
#     age     education      marital_status relationship  class      fare  \
# 0  16.0           NaN                 NaN          NaN      3   18.0000
# 1  50.0       Masters            Divorced    Unmarried      1   28.7125
# 2  40.0  Some-college           Separated    Unmarried      1  134.5000
# 3  16.0           NaN                 NaN          NaN      3   39.6875
# 4  30.0       HS-grad  Married-civ-spouse      Husband      3    8.0500
#
#    sibsp  ...     date_embarked embarked         workclass      occupation  \
# ...

# %% [markdown]
# ## 2

# %%
df.tail(15)
# Out:
#      passenger_id                               name     sex   age  \
# 699           276  Andrews, Miss. Kornelia Theodosia  female  63.0
# 700           633          Stahelin-Maeglin, Dr. Max    male  32.0
# 701           795              Dantcheff, Mr. Ristiu    male  25.0
# 702           883       Dahlberg, Miss. Gerda Ulrika  female  22.0
# 703           172               Rice, Master. Arthur    male   4.0
# 704           423                 Zimmerman, Mr. Leo    male  29.0
# 705            91               Christmann, Mr. Emil    male  29.0
# 706           521              Perreault, Miss. Anne  female  30.0
# 707           173       Johnson, Miss. Eleanor Ileen  female   1.0
# 708           667        Butler, Mr. Reginald Fenton    male  25.0
# 709           689    Fischer, Mr. Eberhard Thelander    male  18.0
# 710           158                    Corn, Mr. Harry    male  30.0
# 711           641             Jensen, Mr. Hans Peder    male  20.0
# ...

# %% [markdown]
# ## 3

# %%
df.sample(20)
# Out:
#      passenger_id                                               name     sex  \
# 345           288                               Naidenoff, Mr. Penko    male
# 334           888                       Graham, Miss. Margaret Edith  female
# 580           183              Asplund, Master. Clarence Gustaf Hugo    male
# 469           562                                  Sivic, Mr. Husein    male
# 118           492                                Windelov, Mr. Einar    male
# 8             317                Kantor, Mrs. Sinai (Miriam Sternin)  female
# 639           170                                      Ling, Mr. Lee    male
# 560           283                          de Pelsmaeker, Mr. Alfons    male
# 131           578          Silvey, Mrs. William Baird (Alice Munger)  female
# 280            52                       Nosworthy, Mr. Richard Cater    male
# 136           748                              Sinkkonen, Miss. Anna  female
# ...

# %% [markdown]
# ## 4

# %%
df.sample(20).to_csv("sample.csv")

# %% [markdown]
# # Exercice 2

# %% [markdown]
# ## 1

# %%
df.shape
# Out:
# (714, 21)

# %% [markdown]
# ## 2

# %%
df.describe()
# Out:
#        passenger_id         age       class        fare       sibsp  \
# count    714.000000  714.000000  714.000000  714.000000  714.000000
# mean     448.582633   29.690476    2.236695   34.694514    0.512605
# std      259.119524   14.517803    0.838250   52.918930    0.929783
# min        1.000000    1.000000    1.000000    0.000000    0.000000
# 25%      222.250000   20.000000    1.000000    8.050000    0.000000
# 50%      445.000000   28.000000    2.000000   15.741700    0.000000
# 75%      677.750000   38.000000    3.000000   33.375000    1.000000
# max      891.000000   80.000000    3.000000  512.329200    5.000000
#
#             parch  hours_per_week  capital_gain  capital_loss    survived
# count  714.000000      614.000000    714.000000    714.000000  714.000000
# mean     0.431373       39.744300    595.250700     67.107843    0.406162
# std      0.853289       12.353735   4375.747007    345.922761    0.491460
# ...

# %% [markdown]
# ## 3

# %%
df.describe(include=['object'])
# Out:
#                                    name   sex education marital_status  \
# count                               714   714       614            614
# unique                              714     2        13              6
# top     Vander Planke, Mr. Leo Edmondus  male   HS-grad  Never-married
# freq                                  1   453       227            276
#
#        relationship     date_embarked embarked workclass occupation  \
# count           614               714      712       614        614
# unique            6                33        3         8         13
# top         Husband  10/04/1912 13:30        S   Private      Sales
# freq            197                47      554       443         80
#
#        native_country income
# count             614    714
# unique              2      3
# top     United-States  <=50K
# freq              600    504

# %% [markdown]
# ## 4

# %%
print(df["workclass"].unique())
# Out:
# [nan 'Local-gov' 'Private' 'Self-emp-not-inc' 'Self-emp-inc' '?'
#  'State-gov' 'Federal-gov' 'Without-pay']

# %% [markdown]
# # Exercice 3

# %% [markdown]
# ## 1

# %%
df[df["education"] == "Masters"]
# Out:
#      passenger_id                                               name     sex  \
# 1             178                         Isham, Miss. Ann Elizabeth  female
# 7             526                                 Farrell, Mr. James    male
# 35            823                    Reuchlin, Jonkheer. John George    male
# 117           836                        Compton, Miss. Sara Rebecca  female
# 121           519  Angle, Mrs. William A (Florence "Mary" Agnes H...  female
# 126           154                    van Billiard, Mr. Austin Blyler    male
# 134           168    Skoog, Mrs. William (Anna Bernhardina Karlsson)  female
# 195           124                                Webber, Miss. Susan  female
# 208           714                         Larsson, Mr. August Viktor    male
# 230           615                    Brocklebank, Mr. William Alfred    male
# 274           450                     Peuchen, Major. Arthur Godfrey    male
# ...

# %% [markdown]
# ## 2

# %%
df[df["class"] == 1]
# Out:
#      passenger_id                                               name     sex  \
# 1             178                         Isham, Miss. Ann Elizabeth  female
# 2             320  Spedden, Mrs. Frederic Oakley (Margaretta Corn...  female
# 10            790                           Guggenheim, Mr. Benjamin    male
# 12             24                       Sloper, Mr. William Thompson    male
# 15             97                          Goldschmidt, Mr. George B    male
# ..            ...                                                ...     ...
# 688           431          Bjornstrom-Steffansson, Mr. Mauritz Hakan    male
# 692           631               Barkworth, Mr. Algernon Henry Wilson    male
# 699           276                  Andrews, Miss. Kornelia Theodosia  female
# 700           633                          Stahelin-Maeglin, Dr. Max    male
# 706           521                              Perreault, Miss. Anne  female
#
# ...

# %% [markdown]
# ## 3

# %%
SinglePassengers = df[df["relationship"] == "Unmarried"]

# %% [markdown]
# ## 4

# %%
SinglePassengers[['name', 'sex', 'age', 'education', 'marital_status', 'native_country']]
# Out:
#                                                   name     sex   age  \
# 1                           Isham, Miss. Ann Elizabeth  female  50.0
# 2    Spedden, Mrs. Frederic Oakley (Margaretta Corn...  female  40.0
# 14                                    Osman, Mrs. Mara  female  31.0
# 31   Rothes, the Countess. of (Lucy Noel Martha Dye...  female  33.0
# 71   Swift, Mrs. Frederick Joel (Margaret Welles Ba...  female  48.0
# 73   Vander Planke, Mrs. Julius (Emelia Maria Vande...  female  31.0
# 84   Louch, Mrs. Charles Alexander (Alice Adelaide ...  female  42.0
# 107                    Goncalves, Mr. Manuel Estanslas    male  38.0
# 123                                Anderson, Mr. Harry    male  48.0
# 125           Harper, Mrs. Henry Sleeper (Myna Haxtun)  female  49.0
# 131          Silvey, Mrs. William Baird (Alice Munger)  female  39.0
# 134    Skoog, Mrs. William (Anna Bernhardina Karlsson)  female  45.0
# 142                   Widegren, Mr. Carl/Charles Peter    male  51.0
# ...

# %% [markdown]
# # Exercice 4

# %% [markdown]
# ## 1

# %%
df.isnull().sum()
# Out:
# passenger_id        0
# name                0
# sex                 0
# age                 0
# education         100
# marital_status    100
# relationship      100
# class               0
# fare                0
# sibsp               0
# parch               0
# date_embarked       0
# embarked            2
# workclass         100
# occupation        100
# hours_per_week    100
# capital_gain        0
# capital_loss        0
# native_country    100
# income              0
# survived            0
# dtype: int64

# %% [markdown]
# ## 2
# On peut compléter la colonne ooccupation grâce à la colonne income quand la personne n'a pas de revenu i.e. "unemployed", idem pour la colonne hours_per_week

# %% [markdown]
# ## 3

# %%
df["occupation"].fillna(inplace=True, value="Unemployed")
# Out:
# /var/folders/kk/g3kdq02d0hxbdwtsfqj42tj00000gn/T/ipykernel_16774/1870625631.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["occupation"].fillna(inplace=True, value="Unemployed")

# %%
df["workclass"] = df["workclass"].fillna(value="Unemployed")

# %%
df["hours_per_week"].where(cond=df["hours_per_week"].notna(), inplace=True, other=0)
# Out:
# /var/folders/kk/g3kdq02d0hxbdwtsfqj42tj00000gn/T/ipykernel_16774/3928940630.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["hours_per_week"].where(cond=df["hours_per_week"].notna(), inplace=True, other=0)

# %% [markdown]
# ## Exercie 5

# %% [markdown]
# ## 1

# %%
df.sort_values("hours_per_week")
# Out:
#      passenger_id                              name     sex   age  education  \
# 0             334   Vander Planke, Mr. Leo Edmondus    male  16.0        NaN
# 346           148  Ford, Miss. Robina Maggie "Ruby"  female   9.0        NaN
# 74             51        Panula, Master. Juha Niilo    male   7.0        NaN
# 349           765            Eklund, Mr. Hans Linus    male  16.0        NaN
# 350           436         Carter, Miss. Lucile Polk  female  14.0        NaN
# ..            ...                               ...     ...   ...        ...
# 435           735      Troupiansky, Mr. Moses Aaron    male  23.0    HS-grad
# 643           544                 Beane, Mr. Edward    male  32.0    HS-grad
# 517           222              Bracken, Mr. James H    male  27.0    HS-grad
# 77            632       Lundahl, Mr. Johan Svensson    male  51.0  Doctorate
# 46             74       Chronopoulos, Mr. Apostolos    male  26.0    HS-grad
#
# ...

# %% [markdown]
# ## 2

# %%
df.groupby("occupation")["capital_loss"].mean()
# Out:
# occupation
# ?                     83.025000
# Adm-clerical          39.480519
# Craft-repair         133.500000
# Exec-managerial       59.478873
# Farming-fishing       98.173913
# Handlers-cleaners      0.000000
# Machine-op-inspct     90.000000
# Other-service         72.362319
# Prof-specialty       125.056338
# Protective-serv        0.000000
# Sales                 79.650000
# Tech-support           0.000000
# Transport-moving      67.392857
# Unemployed             0.000000
# Name: capital_loss, dtype: float64

# %% [markdown]
# ## 3

# %%
df.groupby("occupation")[].median() # je ne sais pas quelle colonne faut-il prendre

# %% [markdown]
# ## 4

# %%
df.groupby("income").agg({'fare': ['min', 'max'], 'age': ['min', 'max'], 'capital_gain': ['min', 'max'], 'capital_loss': ['min', 'max']})
# Out:
#             fare             age       capital_gain          capital_loss  \
#              min       max   min   max          min      max          min
# income
# <=50K      0.000  512.3292  17.0  80.0          0.0   4865.0          0.0
# >50K       0.000  512.3292  25.0  74.0          0.0  99999.0          0.0
# no income  7.225  211.3375   1.0  16.0          0.0      0.0          0.0
#
#
#               max
# income
# <=50K      2603.0
# >50K       2415.0
# no income     0.0

# %% [markdown]
# # Exercice 6

# %%
plt = df["age"].hist()
plt.set_xlabel("Age")
plt.set_ylabel("Effectif")
plt.set_title("Répartition des ages")
# Out:
# Text(0.5, 1.0, 'Répartition des ages')

# %% [markdown]
# ## Exercice 6bis

# %%
maj = df[df["age"] >= 18]
pie = maj["marital_status"].value_counts().plot.pie()
pie.set_ylabel("")
pie.set_title("Camembert des répartition des situation matrimoniales")
# Out:
# Text(0.5, 1.0, 'Camembert des répartition des situation matrimoniales')

# %% [markdown]
# ## Exercice 7

# %% [markdown]
# ## 1

# %%
df.columns
# Out:
# Index(['passenger_id', 'name', 'sex', 'age', 'education', 'marital_status',
#        'relationship', 'class', 'fare', 'sibsp', 'parch', 'date_embarked',
#        'embarked', 'workclass', 'occupation', 'hours_per_week', 'capital_gain',
#        'capital_loss', 'native_country', 'income', 'survived'],
#       dtype='object')

# %%
Titanic = df[['passenger_id', 'class', 'fare', 'sibsp', 'parch', 'date_embarked',
       'embarked', 'survived']]
Career = df[['workclass', 'education', 'marital_status', 'occupation', 'relationship','hours_per_week', 'capital_gain',
       'capital_loss', 'income', 'native_country']]

# %% [markdown]
# ## 2

# %%
Career.dropna(inplace=True)
# Out:
# /var/folders/kk/g3kdq02d0hxbdwtsfqj42tj00000gn/T/ipykernel_16774/2379575826.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Career.dropna(inplace=True)

# %% [markdown]
# ## 3

# %%
CarExt = pd.read_csv("CareerExtension.csv")
CarConcat = pd.concat([Career,CarExt], ignore_index=True)

# %% [markdown]
# ## 4

# %%
pd.read_csv
